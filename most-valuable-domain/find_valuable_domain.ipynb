# %% [markdown]
# # Find most valuable domain
# I am trying to find the most valuable domain for myself, but I don't which one is the highest value.
#
# To achieve this, I first get 3000 most common English words, then generate a list of domains based on the prefix `bit` + 3000 most common English words then append `.com`, `.ai`, `.io`. For example: `bitapple.com`, `bitapple.ai`, `bitapple.io`. Then use [BitSky](https://bitsky.io) to check whether it is available in [godaddy.com](https://www.godaddy.com/) if it is available then check the estimated value.

# %% [markdown]
# ## Mount google drive folder
# Mount **Google Drive** to `/gdrive` folder

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# ## Read generated available domains file
# Each domain data like this:
# ```json
# {
#   "_id": { "$oid": "5f260c5922ad29001764048b" },
#   "domain": "bitnarratology.com",
#   "price": 99.99,
#   "value": 745,
#   "reasons": [
#     {
#       "dev_only": false,
#       "rank": 8,
#       "Type": "great_extension",
#       "Text": "This tld is the most popular one: .com.",
#       "Title": "Great extension"
#     },
#     {
#       "dev_only": false,
#       "rank": 9,
#       "Sld": "bitnarratology",
#       "Type": "short",
#       "Text": "The sld is 15 characters or less.",
#       "Title": "Short"
#     }
#   ]
# }
#
# ```

# %%
import pandas as pd
import numpy as np
domainsDF = pd.read_json('/gdrive/My Drive/domain/domains.json')

# %% [markdown]
# ## Overview `domains.json`

# %%
domainsDF.describe()
# Out:
#               price          value
# count  4.482870e+05  448287.000000
# mean   9.999000e+01     318.013333
# std    1.620039e-11     443.950877
# min    9.999000e+01       0.000000
# 25%    9.999000e+01     100.000000
# 50%    9.999000e+01     100.000000
# 75%    9.999000e+01     265.000000
# max    9.999000e+01    2237.000000

# %%
domainsDF.shape
# Out:
# (448287, 5)

# %%
domainsDF.head(10)
# Out:
#                         _id  ...                                            reasons
# 0  5f260c5922ad290017640487  ...  [{'dev_only': False, 'rank': 3, 'Domain': 'bit...
# 1  5f260c5922ad290017640488  ...  [{'dev_only': False, 'rank': 9, 'Sld': 'bitnar...
# 2  5f260c5922ad290017640489  ...  [{'dev_only': False, 'rank': 3, 'Domain': 'bit...
# 3  5f260c5922ad29001764048a  ...  [{'dev_only': False, 'rank': 9, 'Sld': 'bitnar...
# 4  5f260c5922ad29001764048b  ...  [{'dev_only': False, 'rank': 8, 'Type': 'great...
# 5  5f260c5922ad29001764048c  ...  [{'dev_only': False, 'rank': 1, 'Keyword': 'na...
# 6  5f260c5922ad29001764048d  ...  [{'dev_only': False, 'rank': 3, 'Domain': 'bit...
# 7  5f260c5922ad29001764048e  ...  [{'dev_only': False, 'rank': 3, 'Domain': 'bit...
# 8  5f260c5c22ad29001764048f  ...  [{'dev_only': False, 'rank': 1, 'Keyword': 'bi...
# 9  5f260c5c22ad290017640490  ...  [{'dev_only': False, 'rank': 8, 'Type': 'great...
#
# [10 rows x 5 columns]

# %% [markdown]
# ## Data Clean
# 1. Remove `_id` and `reason` column
# 2. Trim `domain` column
# 3. Remove duplicate domains

# %% [markdown]
# ### Remove `_id` and `reason`
# `_id` and `reason` dosn't need for find highest value domain, so remove them

# %%
domainsDF = domainsDF.drop(['_id', 'reasons'], axis=1)

# %% [markdown]
# ### Trim `domain` column

# %%
domainsDF['domain'] = domainsDF['domain'].str.strip()
domainsDF.head()
# Out:
#                domain  price  value
# 0     bitnarrator.com  99.99   1255
# 1   bitnarratology.io  99.99    100
# 2      bitnarrator.io  99.99    100
# 3   bitnarratology.ai  99.99    100
# 4  bitnarratology.com  99.99    745

# %% [markdown]
# ### Remove duplicate domains

# %%
domainsDF = domainsDF.drop_duplicates(subset=['domain'])
domainsDF.shape
# Out:
# (162466, 3)

# %% [markdown]
# ## Cost Performance
# Domain value is based on [Godaddy Domain Name Value & Appraisal](https://www.godaddy.com/domain-value-appraisal)
#
# 1. `value_per_dollar`: $Estimate\ Value/Price$
# 2. `value_per_character`: $Estimate\ Value/Domain\ Length$
# 3. `value_per_dollar_character`: $(Estimate\ Value/Price)/Domain\ Length$
#
# > * `Estimate Value`: `value` field
# > * `Price`: `price` field
# > * `Domain Length`: `domain_length` field

# %%
domainsDF['domain_length'] = domainsDF['domain'].str.len()
domainsDF['domain_type'] = domainsDF['domain'].str.split('.').str[-1]
domainsDF['value_per_dollar_character'] = domainsDF['value']/domainsDF['price']/domainsDF['domain_length']
domainsDF['value_per_character'] = domainsDF['value']/domainsDF['domain_length']
domainsDF['value_per_dollar'] = domainsDF['value']/domainsDF['price']
domainsDF.head()
# Out:
#                domain  price  ...  value_per_character  value_per_dollar
# 0     bitnarrator.com  99.99  ...            83.666667         12.551255
# 1   bitnarratology.io  99.99  ...             5.882353          1.000100
# 2      bitnarrator.io  99.99  ...             7.142857          1.000100
# 3   bitnarratology.ai  99.99  ...             5.882353          1.000100
# 4  bitnarratology.com  99.99  ...            41.388889          7.450745
#
# [5 rows x 8 columns]

# %% [markdown]
# ### Cost performance based on Domain Length

# %%
domainsDF = domainsDF.sort_values(by='value_per_character', ascending=False)
pd.set_option('display.max_rows', 500)
domainsDF.head(20)
# Out:
#              domain  price  ...  value_per_character  value_per_dollar
# 9796     bitlion.io  99.99  ...           223.700000         22.372237
# 17880     bitins.io  99.99  ...           216.000000         19.441944
# 410326    bittop.io  99.99  ...           214.666667         19.321932
# 97839     bitsky.io  99.99  ...           214.222222         19.281928
# 405685     bitam.io  99.99  ...           209.750000         16.781678
# 4815      bitmen.io  99.99  ...           209.444444         18.851885
# 408183    bitnew.io  99.99  ...           203.444444         18.311831
# 113159    bittag.io  99.99  ...           197.333333         17.761776
# 25203   bitgreen.io  99.99  ...           194.181818         21.362136
# 407211    bitace.io  99.99  ...           192.000000         17.281728
# 99410    bitside.io  99.99  ...           190.700000         19.071907
# 342010  bitvalue.io  99.99  ...           189.818182         20.882088
# 336563   bittown.io  99.99  ...           189.800000         18.981898
# 403428    bitban.io  99.99  ...           187.666667         16.891689
# 53989    bitblue.io  99.99  ...           187.600000         18.761876
# 4522     bitmesh.io  99.99  ...           187.200000         18.721872
# 10915    bitless.io  99.99  ...           184.500000         18.451845
# 407881     bitne.io  99.99  ...           183.750000         14.701470
# 363618   bitfans.io  99.99  ...           181.900000         18.191819
# 394356  bitcycle.io  99.99  ...           181.545455         19.971997
#
# [20 rows x 8 columns]

# %% [markdown]
# ### Cost performance based on Price

# %%
domainsDF = domainsDF.sort_values(by='value_per_dollar', ascending=False)
pd.set_option('display.max_rows', 500)
domainsDF.head(20)
# Out:
#                  domain  price  ...  value_per_character  value_per_dollar
# 9796         bitlion.io  99.99  ...           223.700000         22.372237
# 12064     bitlattice.io  99.99  ...           169.153846         21.992199
# 70842    bitpelican.com  99.99  ...           153.500000         21.492149
# 25203       bitgreen.io  99.99  ...           194.181818         21.362136
# 116946     bitsystem.io  99.99  ...           174.583333         20.952095
# 342010      bitvalue.io  99.99  ...           189.818182         20.882088
# 341993     bitvalley.io  99.99  ...           173.916667         20.872087
# 337190   bittrawler.com  99.99  ...           144.142857         20.182018
# 394356      bitcycle.io  99.99  ...           181.545455         19.971997
# 30392      bitfinder.io  99.99  ...           166.000000         19.921992
# 394630      bitcrypt.io  99.99  ...           179.454545         19.741974
# 82017       bitradio.io  99.99  ...           178.000000         19.581958
# 17880         bitins.io  99.99  ...           216.000000         19.441944
# 410326        bittop.io  99.99  ...           214.666667         19.321932
# 97839         bitsky.io  99.99  ...           214.222222         19.281928
# 99410        bitside.io  99.99  ...           190.700000         19.071907
# 336563       bittown.io  99.99  ...           189.800000         18.981898
# 57848   bitathletes.com  99.99  ...           126.400000         18.961896
# 52605     bitbrokers.io  99.99  ...           145.769231         18.951895
# 4815          bitmen.io  99.99  ...           209.444444         18.851885
#
# [20 rows x 8 columns]

# %% [markdown]
# ### Cost performance based on Price and Domain Length

# %%
domainsDF = domainsDF.sort_values(by='value_per_dollar_character', ascending=False)
pd.set_option('display.max_rows', 500)
domainsDF.head(20)
# Out:
#              domain  price  ...  value_per_character  value_per_dollar
# 9796     bitlion.io  99.99  ...           223.700000         22.372237
# 17880     bitins.io  99.99  ...           216.000000         19.441944
# 410326    bittop.io  99.99  ...           214.666667         19.321932
# 97839     bitsky.io  99.99  ...           214.222222         19.281928
# 405685     bitam.io  99.99  ...           209.750000         16.781678
# 4815      bitmen.io  99.99  ...           209.444444         18.851885
# 408183    bitnew.io  99.99  ...           203.444444         18.311831
# 113159    bittag.io  99.99  ...           197.333333         17.761776
# 25203   bitgreen.io  99.99  ...           194.181818         21.362136
# 407211    bitace.io  99.99  ...           192.000000         17.281728
# 99410    bitside.io  99.99  ...           190.700000         19.071907
# 342010  bitvalue.io  99.99  ...           189.818182         20.882088
# 336563   bittown.io  99.99  ...           189.800000         18.981898
# 403428    bitban.io  99.99  ...           187.666667         16.891689
# 53989    bitblue.io  99.99  ...           187.600000         18.761876
# 4522     bitmesh.io  99.99  ...           187.200000         18.721872
# 10915    bitless.io  99.99  ...           184.500000         18.451845
# 407881     bitne.io  99.99  ...           183.750000         14.701470
# 363618   bitfans.io  99.99  ...           181.900000         18.191819
# 394356  bitcycle.io  99.99  ...           181.545455         19.971997
#
# [20 rows x 8 columns]
